# %% [markdown]
# <a href="https://colab.research.google.com/github/hariPrasadCoder/8-pointer-analysis/blob/hari/Amazon_8_pointer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
page = requests.get('https://finance.yahoo.com/quote/MSFT?p=MSFT&.tsrc=fin-srch')
soup = bs(page.content,"lxml")

# %%
summary = soup.find(id='quote-summary')
table = summary.find_all('table')[1]
pe_ratio = float(table.find_all('tr')[2].text.split(')')[1])
pe_ratio
# Out:
# 38.01

# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.4 MB 6.3 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'52WeekChange': 0.48777556,
#  'SandP52WeekChange': 0.26514983,
#  'address1': 'One Microsoft Way',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 339.9,
#  'askSize': 900,
#  'averageDailyVolume10Day': 32709140,
#  'averageVolume': 26922509,
#  'averageVolume10days': 32709140,
#  'beta': 0.872727,
#  'beta3Year': None,
#  'bid': 339.79,
#  'bidSize': 1300,
#  'bookValue': 20.242,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Redmond',
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 340.105,
#  'currentRatio': 2.165,
#  'dateShortInterest': 1638230400,
#  'dayHigh': 340.69,
#  'dayLow': 335.43,
#  'debtToEquity': 51.938,
#  'dividendRate': 2.48,
#  'dividendYield': 0.0074,
#  'earningsGrowth': 0.489,
#  'earningsQuarterlyGrowth': 0.476,
#  'ebitda': 85745000448,
#  'ebitdaMargins': 0.48648998,
#  'enterpriseToEbitda': 28.704,
#  'enterpriseToRevenue': 13.964,
# ...

# %%
msft.financials
# Out:
#                                          2021-06-30  ...  2018-06-30
# Research Development                     2.0716e+10  ...  1.4726e+10
# Effect Of Accounting Charges                   None  ...        None
# Income Before Tax                        7.1102e+10  ...  3.6474e+10
# Minority Interest                              None  ...        None
# Net Income                               6.1271e+10  ...  1.6571e+10
# Selling General Administrative           2.5224e+10  ...  2.2223e+10
# Gross Profit                            1.15856e+11  ...  7.2007e+10
# Ebit                                     6.9916e+10  ...  3.5058e+10
# Operating Income                         6.9916e+10  ...  3.5058e+10
# Other Operating Expenses                       None  ...        None
# Interest Expense                          -2.33e+09  ...  -2.733e+09
# Extraordinary Items                            None  ...        None
# Non Recurring                                  None  ...        None
# ...
